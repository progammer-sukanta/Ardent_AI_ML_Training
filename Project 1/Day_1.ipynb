# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Variables,Data type,Operators

# %%
# Caluculate area of a triangle

h =20
b= 10
area=1/2*b*h
print(area)
# Out:
# 100.0

# %% [markdown]
# Understa f-string

# %%
# Caluculate area of a triangle

h =20
b= 10

print("the area 1s", 1/2*b*h)
print(f"The area is: {1/2*b*h}")
# Out:
# the area 1s 100.0
# The area is: 100.0

# %% [markdown]
# Lists & indexing

# %%
marks =[70 , 85 , 90 , 60]

print (marks)
print (marks)

# %% [markdown]
# Conditional Statements(if

# %%
age =23

if(age>18):
  print("you can drive")
else:
  print("you can't drive")
# Out:
# you can drive

# %%
# Largest among three numbers

a,b,c= 10, 20, 30

if(a>b and a>c):
  print("a is largest")
elif:(b>a and b>c):
  print("b is largest ")
else:(c>a and c>b):
  print("c is largest ")
# Out:
#   File "/tmp/ipython-input-1529905605.py", line 7
#     elif:(b>a and b>c):
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# **UNDERSTAND MODULES**

# %%
# print current date & time

import datetime

a = datetime.datetime.now()
print(f"the current date & time is:{a}")
# Out:
# the current date & time is:2026-02-18 07:28:06.699651

# %% [markdown]
# Loops : for , while

# %%
# print 1-100 using for loop

for i in range( 10,3, -2):
  print(i)
# Out:
# 10
# 8
# 6
# 4

# %%
# print 1-100 using for loop

for i in range( 1,11):
  print(i)

# %% [markdown]
# string & methods

# %%
name ="Ardent"

print(name)

print(name.upper())
print(name.lower())
# Out:
# Ardent
# ARDENT
# ardent

# %%
# function to calulate average

def avg(phy, che, math):
  return (+phy+che+math)/3

print(avg(50,60,70))
# Out:
# 60.0
